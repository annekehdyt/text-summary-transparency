# %%
import pandas as pd
import pickle
import numpy as np
from sklearn.tree import DecisionTreeClassifier 
from sklearn.model_selection import train_test_split

# %%
def open_pickle(path):
    import pickle
    with open(path, 'rb') as f:
        X = pickle.load(f)
    return X

X_train_original = open_pickle('../data/imdb/imdb_original_preprocessed_xtrain.pickle')
X_test_original = open_pickle('../data/imdb/imdb_original_preprocessed_xtest.pickle')
y_train_original = open_pickle('../data/imdb/imdb_original_preprocessed_ytrain.pickle')
y_test_original = open_pickle('../data/imdb/imdb_original_preprocessed_ytest.pickle')

# %%
from sklearn.feature_extraction.text import CountVectorizer

token = r"(?u)\b[\w\'/]+\b"
cv = CountVectorizer(min_df = 100, token_pattern=token, lowercase=True, binary=True)
X_train = cv.fit_transform(X_train_original)
X_test = cv.transform(X_test_original)

# %% [markdown]
# ### Extract list

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression(random_state=42, penalty='l1')
clf.fit(X_train, y_train_original)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l1', random_state=42, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
coef = clf.coef_[0]
indices = np.argsort(np.absolute(coef))[::-1]
word = cv.get_feature_names()

# %%
word_list = [word[i] for i in indices[:100]]

# %%
word_list
# Out:
# ['7/10',
#  '3/10',
#  '1/10',
#  '4/10',
#  '2/10',
#  '8/10',
#  'unwatchable',
#  'refreshing',
#  'incoherent',
#  'unfunny',
#  'stinker',
#  'waste',
#  '10/10',
#  'disappointment',
#  'poorly',
#  'behave',
#  'superbly',
#  'worst',
#  'miscast',
#  'flawless',
#  'uninspired',
#  '9/10',
#  'appalling',
#  'pointless',
#  'lousy',
#  'cardboard',
#  'boredom',
#  'forgettable',
#  'mildly',
#  'obnoxious',
#  'hooked',
#  'awful',
#  'mst3k',
#  'haunting',
#  'fails',
#  'fest',
#  'wooden',
#  'furthermore',
#  'laughable',
#  'alright',
#  'dull',
#  'dimensional',
#  'captures',
#  'appreciated',
#  'noir',
#  'troubled',
#  'uninteresting',
#  'wasting',
#  'rare',
#  'incredible',
#  'dreadful',
#  'junk',
#  'lacks',
#  'credibility',
#  'existed',
#  'avoid',
#  'disappointing',
#  'wonderfully',
#  'batman',
#  'ripped',
#  'dramas',
#  'underrated',
#  'monkey',
#  'outer',
#  'remotely',
#  'tight',
#  'ideal',
#  'smooth',
#  'mess',
#  'gem',
#  'redeeming',
#  'funniest',
#  'excellent',
#  'hype',
#  'prince',
#  'trite',
#  'driven',
#  'generous',
#  'boring',
#  'delightful',
#  'pretentious',
#  'executed',
#  'steals',
#  'dire',
#  'balance',
#  'endless',
#  'unintentional',
#  'surprisingly',
#  'unconvincing',
#  'devoid',
#  'and/or',
#  'superb',
#  'stupidity',
#  'fashioned',
#  'insult',
#  'badly',
#  'pathetic',
#  'affect',
#  'jackie',
#  'teach']

# %% [markdown]
# ### Extract 'k window' phrase

# %%
X_train_original[0]
# Out:
# 'silent night, deadly night 5 is the very last of the series, and like part 4, it is unrelated to the first three except by title and the fact that it is a christmas-themed horror flick.except to the oblivious, there is some obvious thing going on here...mickey rooney plays a toymaker named joe petto and his creepy son\'s name is pino. ring a bell, anyone? now, a little boy named derek heard a knock at the door one evening, and opened it to find a present on the doorstep for him. even though it said "do not open till christmas", he begins to open it anyway but is stopped by his dad, who scolds him and sends him to bed, and opens the gift himself. inside is a little red ball that sprouts santa arm and a head, and proceed to kill dad. oop, maybe he should have left well-enough alone. of course derek is then traumatized by the incident since he watched it from the stair, but he does not grow up to be some killer santa, he just stops talking.there is a mysterious stranger lurking around, who seems very interested in the toy that joe petto makes. we even see him buying a bunch when derek\'s mom takes him to the store to find a gift for him to ing him out of his trauma. and what exactly is this guy doing? well, we are not sure but he does seem to be taking these toy apart to see what makes them tick. he does keep his landlord from evicting him by promising him to pay him in cash the next day and present him with a "larry the larvae" toy for his kid, but of course "larry" is not a good toy and gets out of the box in the car and of course, well, thing are not pretty.anyway, eventually what is going on with joe petto and pino is of course revealed, and as with the old story, pino is not a "real boy". pino is probably even more agitated and naughty because he suffers from "kenitalium" (a smooth plastic crotch) so that could account for his evil way. and the identity of the lurking stranger is revealed too, and there is even kind of a happy ending of sort. whee.a step up from part 4, but not much of one. again, brian yuzna is involved, and screaming mad george, so some decent special effect, but not enough to make this great. a few leftover from part 4 are hanging around too, like clint howard and neith hunter, but that does not really make any difference. anyway, i now have seeing the whole series out of my system. now if i could get some of it out of my ain. 4 out of 5.'

# %%
import nltk, re, pprint
from nltk import word_tokenize

# %%
len(word_tokenize(X_train_original[0]))
# Out:
# 534

# %%
vocab = cv.vocabulary_

# %%
vocab['affect']
# Out:
# 119

# %%
X_tr_phrase = []
token_list = []
k = 2

for doc in X_train_original:
    token_list = []
    token = word_tokenize(doc)
    for i,tok in enumerate(token):
        for j, word in enumerate(word_list):
            if tok==word:
                # Check if it reach end of document
                if i>=len(token)-1-k:
                    break
                
                join = ' '.join(token[i-k:i+k+1])
                token_list.append(join)
    
    X_tr_phrase.append(token_list)

# %%
len(X_tr_phrase)
# Out:
# 25000

# %%
len_track = []
for doc in X_tr_phrase:
    len_track.append(len(doc))
len_track = np.asarray(len_track)

# %%
np.argmax(len_track)
# Out:
# 520

# %%
X_tr_phrase[520]
# Out:
# ['some very poorly executed low',
#  'very poorly executed low speed',
#  'are very badly shot ,',
#  'distant and badly timed camera',
#  'is equally unconvincing , so',
#  'after another pathetic chase sequence',
#  'most downright laughable and hideously',
#  'and hideously awful special effect',
#  'window with awful sound effect',
#  'is so badly done and',
#  'with the laughable effect ,',
#  'effect , poorly executed car',
#  ', poorly executed car chase',
#  'chase , awful acting and',
#  'the most poorly done ,',
#  'low budget mess of amovie',
#  'wretched , poorly made ,',
#  'made , poorly edited ,',
#  'edited , poorly paced and',
#  'drivel that fails on all']

# %%
from sklearn.model_selection import train_test_split

'''
Assuming the label is already binarized
'''


class ExtractWindowTerms():
    def __init__(self, X_tr, y_tr, train_test_split=False, random_state=42, test_size=(1./3)):
        self.X_tr = X_tr
        self.y_tr = y_tr
        self.random_state = random_state
        self.test_size = test_size
        self.token = r"(?u)\b[\w\'/]+\b"
        
        if train_test_split:
            self.X_tr, self.X_te, self.y_tr, self.y_te = train_test_split(
                self.X_tr, 
                self.y_tr, 
                test_size=self.test_size, 
                random_state=self.random_state)
        
    def extract_word_list(self, min_df=100, penalty='l1', n_word = 100):
        cv = CountVectorizer(min_df = min_df, token_pattern=self.token, lowercase=True, binary=True)
        self.X_train = cv.fit_transform(self.X_tr)
        
        clf = LogisticRegression(random_state=self.random_state, penalty=penalty)
        clf.fit(self.X_train, self.y_tr)
        
        coef = clf.coef_[0]
        indices = np.argsort(np.absolute(coef))[::-1]
        word = cv.get_feature_names()
        self.word_list = [word[i] for i in indices[:n_word]]
        
        return self.word_list
    
    def k_window_slicing(self, X, k_window=2):
        
        X_phrase = []
        token_list = []

        for doc in X:
            token_list = []
            token = word_tokenize(doc)
            
            for i,tok in enumerate(token):
                for j, word in enumerate(word_list):
                    if tok==word:
                        # Check if it reach end of document
                        if i>=len(token)-1-k_window:
                            break

                        join = ' '.join(token[i-k_window:i+k_window+1])
                        token_list.append(join)

            X_phrase.append(token_list)
            
        return X_phrase

# %%
ext = ExtractWindowTerms(X_train_original, y_train_original)

# %%
_ = ext.extract_word_list()

# %%
X_phrase = ext.k_window_slicing(X_train_original, k_window=3)

# %%
[i for i in X_phrase if len(i)>0]
# Out:
# [["'' ( a smooth plastic crotch )"],
#  ['short film of excellent quality that can'],
#  [': and the unintentional humour.the film opens',
#   'truly bad and unconvincing gay banter between',
#   'this display of awful dialog-writing , we'],
#  ['one point , driven to frustration ,', 'he is the worst of us gone'],
#  ['watched 12/7/2002 - 3/10 ( dir-steve purcell',
#   "care for this boring ` adventure '"],
#  ['of cinema , haunting , and incredibly'],
#  ['movie is utterly laughable and has about', 'that piece of junk , but you'],
#  ["'' was an excellent choice because of",
#   'overtone of film noir . fortunately ,',
#   'as colman had excellent support from signe'],
#  ['this film is boring . where are',
#   'is stiff , wooden and forced .',
#   'they utter their pointless line , they',
#   'like you got ripped off after seeing'],
#  ['was probably the worst dcom ever .'],
#  ['sex , individual dramas and unemployment are',
#   'heroin slavery.without being boring and moralist ,'],
#  [', person so boring and nondescript that',
#   'which he does superbly , so that',
#   'she is simply incredible . she portrays',
#   '. she is wonderfully supported by old',
#   'leicester . a superb performance is given',
#   'out to be pathetic , with all',
#   'all these essentially uninteresting person caught up'],
#  ['after watching the batman animation . its',
#   'animation series in batman in the early',
#   'doing trying to mess with the winning',
#   'exactly the way batman was intended to',
#   'wb had to mess this up with',
#   'with some tripe batman of the future',
#   'joker does not remotely resemble the joker'],
#  ['time an annoying mess . shot on'],
#  ['and miss , and/or success is blind'],
#  ['absence of the superb ryuhei kitamura at',
#   'has a corkscrew mess of a story',
#   'with too many dull character stabbing each',
#   '- are completely devoid of any sort',
#   'that they are poorly choreographed and abysmally',
#   'film , the stupidity of the plot',
#   'just a colossal disappointment . any merit'],
#  ['or even that awful american werewolf in',
#   '. the only redeeming value of this'],
#  ['you wont feel ripped off as i'],
#  ['', '( probably ) unintentional campy laughs in'],
#  [') with an excellent background . it'],
#  ['called the film pathetic and claimed no',
#   'truth and i appreciated it for finally'],
#  ['is just plain pathetic . just because'],
#  ['curtiz showing an incredible command of the'],
#  ['have been very disappointing had very been',
#   'house is a mess , litter and'],
#  ['entire film was poorly dubbed and made'],
#  ['looking for a surprisingly fun ride through'],
#  ['whatsoever dragging and boring till end you'],
#  ['to mention the incredible soundtrack that gives',
#   'i give this 9/10 . to be'],
#  ['one of the worst director in the', 'he made this stinker . i was'],
#  ['the mom ) behave as though they'],
#  ['interesting character , excellent portrayal , writing'],
#  ['', 'gave it an 8/10 , but let'],
#  ['( a divinely smooth and commanding performance'],
#  ['story presented a delightful 14 year old',
#   '. with an excellent supporting cast especially'],
#  ['', 'a movie as flawless as this .', "'' as the trite clich they are"],
#  ['and an evil prince who owns part', 'the same evil prince has plan to'],
#  ['dom delouise somewhat miscast but certainly watchable'],
#  ['is such an excellent actress and i'],
#  ['say , `` alright ! i have'],
#  ['the soundtrack is awful ... ) ,',
#   'it is just awful . like ,',
#   '9 from outerspace awful . like ,',
#   'i soil myself awful . try watching'],
#  ['there are no redeeming quality to this'],
#  ['that sappy emoted junk , but real',
#   'paul reiser was excellent , although ,'],
#  ['it is a waste of the film'],
#  ["' is a superb peter bogdanovich that", 'ritter who is superb . and of'],
#  ['he could play delightful old codger ,'],
#  ['it is a waste of my time'],
#  ['sam neill is excellent as michael chamberlain'],
#  ['well . many disappointment soon followed ('],
#  ['contributed in these waste of time please'],
#  ['he was probably miscast as lucas buck'],
#  ['overall rating : 8/10 - big family'],
#  ['am giving this pretentious piece of garbage',
#   'hell.damn this disgusting waste of time.i pray'],
#  ['doodlebop do not teach the alphabet or',
#   'not suppose to teach your child about'],
#  ["`` a total waste of time ''"],
#  ['one of the worst film i have'],
#  [', despite the smooth exterior , shows',
#   'spacey not only steals many scene from'],
#  ['stupid.please do not waste your time hoping'],
#  ['firefighter during the worst terrorist attack of'],
#  ['piece of human waste to having each',
#   'as the `` worst film ever made',
#   'had without the poorly written character ,',
#   'that unnecessary and unfunny comedy . a',
#   'word . a generous amount of blood'],
#  ['of that he lacks his usual charisma',
#   ', episodic , trite , shallow and',
#   ', shallow and forgettable cop movie .'],
#  ['warehouse.once again another disappointing movie that i'],
#  ['he signed the superb under the volcano',
#   'niro but sounds unconvincing coming from jack',
#   'direction is as uninteresting as everything else'],
#  ['joan crawford is excellent as the socialite-turned-moll'],
#  [', really stupid waste of film.do not',
#   'of film.do not waste your time watching'],
#  ['like the sadly miscast american version of',
#   'just a bit dull ) in england',
#   ', as simply boredom with puppet .',
#   'for the single worst show on the',
#   "one interminable , unfunny lesson '' )"],
#  ['.one of my worst flick fear has'],
#  ['embarrassing , safe and/or dull ( the', ', safe and/or dull ( the pianist'],
#  ['to be his worst movie ever .'],
#  ['this movie terribly lacks . sure ,', 'an overuse of pointless death , and'],
#  ['zombie has no redeeming feature . i',
#   'happening , the awful choice of when',
#   'actor mumbling their trite and tedious line',
#   'plan nine from outer space or santa',
#   'slowly close in boredom . which is'],
#  ['to be a dull , dis-interesting ,', 'stuck in a poorly made vehicle which'],
#  ['the story is excellent , but ,'],
#  ['and it is refreshing to see a'],
#  ['are noticing the tight corner of their',
#   'use of a delightful scene with myrna'],
#  ['some of the worst line to narrate',
#   'when the film fails to motivate ,',
#   'it would be worst if we had',
#   '. the final insult was the ``'],
#  [', annoying and pointless character , all'],
#  ['one of the worst movie of all', 'lot more . avoid at all cost'],
#  ['movie was so poorly written and directed',
#   'might add are poorly done ) and',
#   'music was very disappointing because it was',
#   '( 10 being excellent , 1 being',
#   'her acting was laughable . when she',
#   'i think the worst thing about this',
#   'all , a disappointing movie , but'],
#  ['films makes no pretentious effort to hide'],
#  ['this bilge did.since wasting 90 minute of'],
#  ['really terrible.the only redeeming feature about this',
#   'what is the worst vampire movie i',
#   'choreography is the worst i have ever'],
#  ['a sequel.8/10quality : 9/10 entertainment : 7/10'],
#  ['in this horrible waste of time called',
#   'complete and total waste of time -'],
#  [', with perverted monkey jumping and clapping.she'],
#  ['this is the worst film i have',
#   'i would have appreciated someone warning me'],
#  ['. so please avoid at all cost'],
#  ['disgrace . this dreadful event should be',
#   'to a partially incoherent chilean-english accent.2 )'],
#  ['version of this gem ( your loss', 'us sitcom ! waste of time and'],
#  ['',
#   'half hour is alright the rest is',
#   'the rest is boring and not funny',
#   '. just plain boring klayman running into'],
#  ['district attorney is wooden is a gross'],
#  ['should receive the worst possible rating it'],
#  ['this movie is boring . the only'],
#  ['last episode was dull , dull ,',
#   'was dull , dull , dull .',
#   ', dull , dull . the whole'],
#  ['picture , boorman captures the natural beauty',
#   'that jon voight steals the show with'],
#  ['watched . it fails to a fitting',
#   'is almost an insult to the memory',
#   'explanatory scene are awful . the chief',
#   'army staff looks unconvincing . to make'],
#  ['this is the worst documentary to come'],
#  ['line of a poorly written xena episode',
#   "kathy long 's tight red short were",
#   'than to be mildly amused for a'],
#  ['. i would avoid this one at'],
#  ['the moon is superbly made , a',
#   'sobs with my dull prose , will',
#   'joy and a gem , a film'],
#  [', always a delightful grandmother in this'],
#  [', with a flawless idea , and',
#   'short is a gem . while i',
#   'one of the worst of the first'],
#  ['.looking for more redeeming factor for this',
#   'it is to teach a lesson .',
#   "'s which are excellent and sure to"],
#  ['do not ever waste your time watching'],
#  ['human actor . furthermore i like the',
#   "'' i have appreciated his naive way"],
#  ['color are a disappointment ) . robin',
#   'there is nothing remotely funny ( satirical',
#   "of the very worst `` big ''"],
#  ['violent confrontation is pathetic . the end'],
#  [', what a disappointment . rented it',
#   'bother you will waste time and money.boring'],
#  ['of the best dramas ever . 10/10'],
#  ['given this film 10/10 , however some',
#   'she is pretty underrated as a serious'],
#  ['',
#   'is a film noir set in a',
#   ', in typical noir fashion , thing',
#   'like most great noir , it is',
#   'it is also wonderfully paced , sucking',
#   'again . it lacks the verbal wit',
#   'of what a noir should be ,',
#   'work is likewise disappointing . there is',
#   'of gangster ( noir cage ) which',
#   'the set design fails to reinforce it',
#   'reinforce it . 7/10 - otto seems',
#   'of what a noir is , rather',
#   'possibility of where noir can go .',
#   'second tier film noir . it is',
#   'engaging , but lacks that extra special'],
#  ['( x ) badly edited { pace', ') a genuine waste of my time.as'],
#  ['character interact is surprisingly realistic- there are',
#   'for them to affect me much emotionally'],
#  ['mind as the worst movie of all', 'at least the worst that i would'],
#  ['hopelessly lost in endless and pointless action',
#   'in endless and pointless action scene and'],
#  ['weller are really excellent in this film',
#   ', thriller , dramas , and interesting'],
#  ['toni collette is miscast , and poor', 'made to look laughable ! i really'],
#  ['the best cop dramas ever produced here'],
#  ['the performance are wooden , every sentence',
#   "'monty pythonesque ' endless supply of food"],
#  ['those who love dramas where nothing interesting'],
#  ['us to the worst issue in the'],
#  ['it is slightly boring . in this'],
#  ['one of the worst i have seen'],
#  ['annoying , and boring . there were'],
#  ['all of those awful mario lanza movie',
#   '. so as awful as this movie',
#   'is corny and awful . but the'],
#  ['found it pretty boring with simply crappy'],
#  ['is truly the worst sequel in history'],
#  ['but stupid and boring laughing on repeated'],
#  ['script , the endless makeup , getting',
#   '-- are completely boring . when they'],
#  [", `` the incredible mr. limpet ''",
#   'it is very disappointing . it is',
#   'not because it lacks action or special',
#   'otherwise you risk boring them ( and'],
#  ["'' is a superbly crafted film .", 'far , the funniest movie i have'],
#  ['work are all excellent and at least'],
#  ['toro is again excellent as the charismatic'],
#  ['... ) . 8/10 , but branagh'],
#  ['company is very dire indeed . hardy',
#   ', is direly unfunny ... and its',
#   'most of the unfunny humour here is',
#   "do . runt steals the woman 's"],
#  ['monumental level of stupidity . it gets',
#   'acting is universally appalling . every single',
#   'very possibly the worst song ever recorded'],
#  [''],
#  ['was lush with incredible character development ,',
#   '-- coupled by incredible special effect of',
#   "was also a disappointment . tank 's",
#   'he would even waste his time engaging',
#   'and forget the incredible story inconsistency and'],
#  ['is really a stinker . the acting',
#   'the acting is awful , the direction',
#   'the direction is laughable , and so'],
#  ['i want to waste another 1/336th of'],
#  ['care for a troubled young lad \x96'],
#  ['of a real stinker . about the'],
#  ['. those were poorly done ) ,',
#   'revelation to a monkey and set the',
#   'and set the monkey in front of',
#   'because of how incredible it was --'],
#  ['looked great galloping.the funniest ( albiet unintentionally'],
#  ['done , very pathetic . it is'],
#  ['might be the worst of this rather'],
#  ['is a shining gem in the rubble',
#   'seen as a waste by his peer',
#   'giant digger are driven by steam boiler'],
#  ['the movie is wonderfully romantic in many',
#   'done ) .an excellent movie , especially'],
#  ['up by a haunting childhood . he'],
#  ['? , is forgettable in the cop/estranged-husband/loving-father-of-cute-little-blond-girl',
#   ', contrived and uninteresting movie . the'],
#  ['drift , to avoid the possibility of'],
#  ['has class to teach , a school'],
#  ['transcends into complete boredom , like too'],
#  ['but it is dull , cheesy and',
#   'stupid.special effect are laughable , all actor',
#   'simply awful.do not waste your money ,'],
#  ['film is truly awful , and it',
#   'character are fairly devoid of personality ,',
#   'is tedious and dull . do not'],
#  ['its execution so disappointing . i watched',
#   '? the rather dull narration of the',
#   'narration of the stupidity of an insipid',
#   'there is nothing remotely novel about the'],
#  ['the character are devoid of depth and', 'do decide to waste 2 hour of'],
#  ['soderburgh does an excellent job of setting'],
#  ['',
#   'drawn from the worst cabaret tradition ,',
#   'lowest mark was 1/10 and so i'],
#  [', to my disappointment , chinese hercule',
#   'be over-long , badly choreographed ( apparently',
#   '( apparently by jackie chan ! )',
#   '! ) , badly shot and at'],
#  ['plot less , incoherent shamble that ings',
#   'is a meandering mess as the heroine'],
#  ['bad acting and unintentional humorous scene .'],
#  ['rural neighbourhood is excellent , but what',
#   'ahista was a delightful watch and it'],
#  ['belongs to the noir cycle less by'],
#  ['a dreary , pretentious lengthy saga about'],
#  ['tracey is a superb actor - the', 'with a vague redeeming momant , but'],
#  ['the music is forgettable . i remember'],
#  ['think the movie fails ( in the',
#   'anymore or would behave strangely , the',
#   'the movie seems pointless . we get'],
#  ['this movie is excellent with tremendous sound'],
#  ['makes for a lousy show . perhaps', 'this show a 1/10 , i would'],
#  ["jackson novel 'the haunting of hill house",
#   'well . a haunting masterpiece.the 1963 chiller',
#   "1963 chiller 'the haunting ' stay closely",
#   'the chill are executed even better on',
#   'the movie . excellent ! and then',
#   'remake of the haunting hit the cinemas',
#   'to become somewhat wooden as the film',
#   '. do not waste your money !'],
#  ['in a really awful film ; they'],
#  ['supporting cast was superb . why would'],
#  ['i saw the mst3k version of ``',
#   'cleaner production or mst3k really edited a',
#   'it seemed a waste of money .'],
#  ['movie were quite boring . it focused',
#   '40 minute were excellent . we finally',
#   'the actor are excellent . including the'],
#  ['he was a lousy actor ; not',
#   'with a hopelessly miscast , misdirected travesty'],
#  ['bitter rather than pathetic , full of',
#   'mesmerizing , not devoid of humor though'],
#  ['her and a wonderfully hard-boiled/soft-boiled ben gazzara'],
#  ['is not the worst film i have'],
#  ['-- are completely unfunny . he has'],
#  ['is a very poorly produced product .',
#   '. synthesizer generated uninspired score of lame'],
#  [', with many gem made by both', 'age , never fails to deliver .'],
#  ['was so very badly written . the'],
#  ['importantly , they teach girl and young'],
#  ['not find any redeeming value in it'],
#  ['incredibly , mind-numbingly dull ? the answer',
#   '. there are endless shot of our',
#   'sat there watching endless parade of nothingness'],
#  ['give this movie 7/10 because the villain', 'you are a batman fan and i'],
#  ['wasted in a pathetic , juvenile role'],
#  ['direction throughout is superb . part two'],
#  ['mediocre or plain awful , she has',
#   'two person with incredible ease . and',
#   'in such an unconvincing way that when',
#   'witch with no redeeming value to suddenly',
#   'be the most unconvincing 180 degree turn',
#   ') . equally unconvincing is adriano giannini',
#   'movie -- it lacks any humor and',
#   'devastation in a tight close-up , it'],
#  ['talking about something boring , who occasionally',
#   'character are all forgettable one dimensional cutout',
#   'all forgettable one dimensional cutout , and',
#   'person go is boring ! this show'],
#  ['on merit ; poorly acted , badly', 'poorly acted , badly shot and the'],
#  ['now . the worst aspect are due'],
#  ['bore with an endless recounting of the'],
#  ['ugh . how awful . just another', '. just another junk in the attic'],
#  ['one of the worst movie i have'],
#  ['it takes the awful beautiful person we'],
#  ['at melting the noir theme and the', '. it shoves noir in our faces'],
#  ['her confusion , boredom and annoyance elizabeth',
#   'face , a pretentious foreman ( dana'],
#  ['from what a boring movie you are'],
#  ['has an incredibly dull story involving assassination'],
#  ['into an incredibly awful movie . if'],
#  ['has to be awful , i refuse'],
#  ["and the absolutely unwatchable `` thepsychic ''",
#   'conjob . what mst3k could have done'],
#  ['like this is wasting too much energy',
#   'a couple of delightful shock-moment and there',
#   'gives away a flawless portrayal of a',
#   'to tension and credibility , but that',
#   'will be greatly appreciated by classic horror',
#   "very irritating and lousy underground 80 's"],
#  ['. lovely film noir with a lovely'],
#  ['folk would merely waste the money on', ') grade : 8/10 ( b+ )'],
#  ['and drug and devoid of parent .',
#   'that foster ultimately fails at.despite its age',
#   "movie 's biggest disappointment is that the"],
#  ["'cause the absolutely uninspired and unconvincing shooting",
#   'absolutely uninspired and unconvincing shooting , acting'],
#  ['this is an awful movie . awful',
#   'awful movie . awful enough , that',
#   'and how they behave just does not'],
#  ['that is being generous . just for'],
#  [', he is awful here . not',
#   "henry fonda 's delightful cameo ) that",
#   'is just bloody awful , and the',
#   'say them so badly ! the editing'],
#  ['one of the worst movie ever made'],
#  ['point for its haunting theme song and'],
#  ['the color are superb - would love'],
#  ['movie that encompasses outer space , the'],
#  ['this film are laughable , unfortunately its',
#   'unfortunately has an awful script , awful',
#   'awful script , awful acting and worst',
#   'awful acting and worst of all ,',
#   'of all , awful annoying character .'],
#  ['you want to avoid and this comes',
#   'into an almost unwatchable mess after she',
#   'an almost unwatchable mess after she is'],
#  ['and is ineptly executed . the rape/abuse',
#   'rape/abuse scene are surprisingly restrained and the',
#   "wish '' is laughable . r. bolla"],
#  [', afterward becoming boring and lasting entirely',
#   'it played out excellent and also coincided'],
#  ['and buy this rare film then do'],
#  ['them are : uninteresting , unentertaining ,',
#   'a load of boring crap ! what'],
#  ['one of the worst movie of all'],
#  ['the egyptian one disappointing ) . stragely'],
#  ['1950 it was rare to throw ahab'],
#  ['. you are wasting your time and', 'either . the incredible melting man is'],
#  ['such a shameful waste of otherwise extraordinarily'],
#  ['a far bigger disappointment than i thought',
#   '! do not waste your time or',
#   ', there is awful music blaring throughout'],
#  ['the temptation and jackie wilson in mr.'],
#  ['one of those rare film that established',
#   ', though outrageously awful , is not',
#   'in a hollow pointless way . myra',
#   'he is just obnoxious . again ,',
#   'strike a good balance . even so',
#   'renders her horribly unfunny dialogue with a',
#   'as confused and pointless as the movie.and',
#   'this is a rare movie that actually'],
#  ['was a major disappointment for me .'],
#  ['the acting was superb and the story'],
#  ['not react or behave the way any'],
#  ['3 or 4 pointless , boring chase',
#   '4 pointless , boring chase scene making'],
#  ['loincloth is pretty boring as she pretty', 'at it is worst . lucio fulci'],
#  ['a bunch of junk . i thought', ', was an awful device to show'],
#  ['support system causing dire consequence for many'],
#  ['film . very unfunny was the take'],
#  ['have wanted to waste money renting it'],
#  ['one of the worst actor i have', '. do not waste your time watching'],
#  ['impressively directed and surprisingly well thought through',
#   'flaw in a surprisingly good sci-fi actioner.optimum'],
#  ['( nasty and dull ) or possibly',
#   '( just plain dull ) , but',
#   '. the only redeeming feature was seeing'],
#  ['my top 10 worst film i have'],
#  ["hosting america 's funniest home videos.parent ,",
#   'your kid to stupidity and they will'],
#  ['to be the worst film i have'],
#  ['would be an insult to the old'],
#  ['movie is pretty awful but i have'],
#  ['we have a disappointing virgin and an',
#   'hysterically , the worst assumption have become'],
#  ['display in this waste of film and', 'for just f*cking awful ) . as'],
#  [', much better.still 4/10 since it was'],
#  ['matter by his uninspired and tired rehashing',
#   'away but was driven off . produce',
#   'to the high ideal and standard of'],
#  ['is such a wonderfully delightful character .',
#   'such a wonderfully delightful character . you'],
#  ['to put in mildly . she drives'],
#  [', it was poorly done and not',
#   'her in that mess does not make',
#   'if not the worst ) i have'],
#  ['you want someone badly enough , it'],
#  ['this generic and forgettable action movie ,',
#   'it is truly appalling , and therefore',
#   'entertaining in an unintentional , horrible way'],
#  ['michael keaton an excellent comic performer before'],
#  ['is also an insult to the blade', ', and an insult to everything a'],
#  ['weissmuller ( looking surprisingly aged a year',
#   ', but the worst character is benji',
#   'benji , an obnoxious mailman who sings',
#   'méxico ! ) boring and decidedly of'],
#  ['the pace is dull . the tension', 'bit of its credibility to the musical'],
#  ['job with a wooden character . find'],
#  ['have been much worst if not for'],
#  ['one of the worst movie i ever'],
#  ['is really very dull . aside from'],
#  ['grand plan ultimately fails . corbin bernsen'],
#  ['remark on the mst3k airing . that',
#   'coherent than the mst3k oadcast , owing',
#   'unmotivated in the mst3k version , is',
#   'it into the mst3k version : before'],
#  ['fun.the acting is dreadful , save for',
#   'cast is completely forgettable , except perhaps',
#   'dopey mishmash of dreadful acting , an',
#   'acting , an incoherent script , and'],
#  ['a shrill , obnoxious , woman .',
#   'but how the obnoxious mother kept butting'],
#  ['i see nothing redeeming about this film', 'of it ... 3/10 ( and that'],
#  ['over-confidently promoted tashan poorly bombed at the',
#   'this is the worst movie ever made'],
#  ['by far the worst horror/thriller i have',
#   'not even the worst part of this'],
#  ['longest stretch of unfunny writing and sketch-making',
#   'with the abominably unfunny `` date movie',
#   ") and the disappointing `` click ''"],
#  ['of the most underrated horror film ever'],
#  ['. this film fails on practically every',
#   'it is truly laughable . i could',
#   '. do not waste your time with',
#   'time with a waste of celluloid like',
#   'truly possibly the worst film ever made'],
#  ['of how teenager behave . i do',
#   'enjoy good character driven dramas , then',
#   'good character driven dramas , then see'],
#  ['is barely above pathetic . why liam',
#   'one of the worst performance in recent'],
#  ['this movie on mst3k . and although'],
#  ['its just so boring , in what', 'better . best avoid unless your bored'],
#  ['either . the worst part was the'],
#  ['one of the worst movie i have', 'dialogue is so poorly written that you'],
#  ['actioners.the plot is devoid of any twist'],
#  ['just to be appreciated by his family',
#   'the story is surprisingly minimal . perhaps'],
#  ['one of the worst exponent of that',
#   'philosophy.the film offer excellent acting all around'],
#  ['eric my favorite prince . he was', 'even try to mess with our favorite'],
#  ['flick should always avoid : it is',
#   'is a bit boring . overall ,',
#   'not a total mess . it has'],
#  ['to have some redeeming quality . however'],
#  ['', 'and there was surprisingly smaller mention of'],
#  ['... yawn . boring , pointless ,',
#   '. boring , pointless , utterly stupid',
#   'movie itself is dull dull dull !',
#   'itself is dull dull dull ! bach',
#   'is dull dull dull ! bach and',
#   'save this . boring , pointless and',
#   '. boring , pointless and unknown ('],
#  ['stupidly annoying and unfunny is a reason',
#   'downright infuriating at worst . the gag',
#   'joke that your unfunny friend would say.corky',
#   'plenty of other forgettable joke appear none'],
#  ['house is a mess with toy .',
#   'diverse gang are rare everywhere except hollywood',
#   'i found it refreshing to see a'],
#  ['visual effect are superb and best of'],
#  ['neighbor , a boring legal trial ,'],
#  ['the success of batman . so everyone',
#   'that is something rare these day .',
#   'thug . madonna steals the show as'],
#  ['its time , laughable and used in',
#   'first is the excellent casting of carel'],
#  ['creepiness and the wonderfully powerful dialogue .'],
#  ['dead gets a 3/10 , a little'],
#  ['own segregation.racism certainly existed in one of'],
#  ['be the most pointless and ridiculous television',
#   'is nothing even remotely redeeming or interesting',
#   'nothing even remotely redeeming or interesting about'],
#  ['another of those rare b-movie that bbc2',
#   'seeking out . excellent but rather obscure.rating'],
#  ['one he was incredible . i gave'],
#  ['distributor , this underrated release , a'],
#  ['that this misplaced gem of the disco',
#   'ice-cold bottle of refreshing coca-cola . was'],
#  ['the philly film fest last year ,'],
#  ['is stupid , poorly written and contains'],
#  ['china is an excellent movie that depicts'],
#  ['with some very poorly executed low speed',
#   'some very poorly executed low speed car',
#   'chase are very badly shot , with',
#   'with distant and badly timed camera angle',
#   'else is equally unconvincing , so much',
#   '. after another pathetic chase sequence ,',
#   'the most downright laughable and hideously awful',
#   'laughable and hideously awful special effect i',
#   'every window with awful sound effect that',
#   'it is so badly done and so',
#   'but with the laughable effect , poorly',
#   'laughable effect , poorly executed car chase',
#   'effect , poorly executed car chase ,',
#   'car chase , awful acting and ludicrous',
#   'of the most poorly done , low',
#   ', low budget mess of amovie ever',
#   'a wretched , poorly made , poorly',
#   'poorly made , poorly edited , poorly',
#   'poorly edited , poorly paced and tedious',
#   'budget drivel that fails on all count'],
#  ['past incident still affect us today ,'],
#  ['have made this mess tolerable . we',
#   'is just plain awful . ugly !',
#   'the directing is uninspired and the end'],
#  ['enduring 99 % stupidity . i may',
#   'absurdist quality still fails to make dumbland'],
#  ['the pulp fiction/film noir root from which'],
#  ["drew barrymore 's worst days.the movie starts",
#   "de palma 's underrated thriller , ``",
#   'one of the worst ending of movie',
#   'the dialog are dull and the wooden',
#   'dull and the wooden acting certainly does'],
#  ['rank among the worst i have ever'],
#  ['one of the worst movie i have',
#   'one of the worst actor i have',
#   'scene are the worst i have ever'],
#  ['mutated by toxic waste slug ( who', "'' ( which mst3k deservedly mocked )"],
#  ['is among the worst . an interesting'],
#  ['brown was an excellent gilbert blythe .'],
#  ['football thug is laughable . are we',
#   'the acting is appalling and provides most'],
#  ['( formerly ) tight body left and',
#   'horror movie are remotely linear , or',
#   'as ordinary and dull as the script'],
#  ['production value , awful script , mediocre',
#   'am surprised the mst3k crew never lampooned'],
#  [', is a gem that shines perfectly'],
#  ['way through this incoherent mystery/thriller that is',
#   'story is a mess of b-movie clich'],
#  ['quite amusing . alright , this is', 'a positive , 10/10 review , from'],
#  ['of the two delightful leading lady -'],
#  [', `` that monkey is almost human',
#   'term . they waste time theorizing about',
#   'see how these monkey are crowded together',
#   'where a captive monkey says in sign',
#   'imagine . baby monkey are separated from',
#   'prove that baby monkey crave a ``',
#   'illiant conclusion : monkey have emotion.one chimp'],
#  ['was only a disappointment in that i'],
#  ['his game to surprisingly high level .',
#   'too \x96 very disappointing from the guy'],
#  ['co-watchers.the manuscript is awful , the directing',
#   ': do not waste your time watching'],
#  ['stormtrooper was through excellent use of their',
#   'would have been disappointing if the movie',
#   'these poll are appalling and quite misleading.bottom',
#   'a moment of boredom because each scene'],
#  ['ever seen the excellent mary regan ,'],
#  ['sloppy dialogue , boring futuristic fx and'],
#  ['these short are disappointing . the best',
#   'watch , with excellent , traditional animation'],
#  ['and along with superb editing , should'],
#  ['sleeve hem and badly pilling faic badly',
#   'badly pilling faic badly tailored into baggy'],
#  ["to earth '' fails miserably ; this",
#   'rock is a lousy standup comedian ,',
#   'are in a pointless and unconvincing love',
#   'a pointless and unconvincing love story filled',
#   'so obvious , wooden and straightforward .',
#   'are so many unfunny joke and horrible'],
#  ['hopelessly inept and dull movie in which',
#   'monster are entirely unconvincing . there are'],
#  ['talk , and unfunny bit of business'],
#  ['is cute and delightful as his perky'],
#  ['probably the most boring fashion possible ,',
#   'are just plain laughable ( every line',
#   'a piece of junk , with bad'],
#  ['. sophomoric and pretentious in the worst',
#   'pretentious in the worst way . the',
#   'horse sh*t. the worst offender were the',
#   ', superior , pretentious , preachy manner',
#   "bill bryson 's excellent survey of science"],
#  ['to mccarthyism . furthermore , it builds'],
#  ["it is well executed 'jump ' scene"],
#  ['on ( a surprisingly feature-filled ) dvd'],
#  ['romance , 12 monkey , clerk ,', 'film is an insult to true cult'],
#  ['would want to waste my time looking',
#   'acting is just awful . my least',
#   'i think the funniest moment of the',
#   'in a hilariously unconvincing death . heroine',
#   ', do not waste your time or'],
#  ['make person do awful thing they would'],
#  ['was not even remotely as funny.tip for'],
#  ['and rely on stupidity from person who', 'actor are so wooden . they are'],
#  ['',
#   '. story : pathetic . screenplay :',
#   ', all of pathetic quality . preserve'],
#  ['as anything . batman ta may be',
#   'may be the worst thing to ever',
#   'good . was batman beyond good ?',
#   '. `` the batman is certainly no',
#   ', less experienced batman fighting crime is',
#   'wanted to watch jackie chan adventure ,',
#   'i would watch jackie chan adventure .',
#   'gadget to fight batman . when he',
#   'to be a monkey with dreadlock who',
#   '. what the batman does is it',
#   'you liked about batman comic and lore'],
#  ['what a great gem this is .',
#   'the character are wonderfully interesting to watch'],
#  ['star in a mess of a movie'],
#  ['by far the worst movie i have',
#   '. i generally avoid the crappy one',
#   'there is nothing remotely funny about this',
#   'things- stupid , pointless , and worthless'],
#  ['list is really endless ! so enjoy'],
#  ['thriller . not surprisingly so have all'],
#  ['! it never fails to make me', 'list is truly endless . the scene'],
#  ['is more than awful ; it has',
#   'to be the worst and most retarded',
#   'no one should waste their time watching',
#   'it is the worst film ever -'],
#  ['making it an unconvincing documentary . if',
#   'this is too dull and monotonous .'],
#  ['to display his disappointment ! i laughed'],
#  ['is not the worst film ever made'],
#  ['house forms the ideal turf for the',
#   'to be so boring and uneventful .',
#   'is a pretty dreadful movie . the',
#   "low-budgeted 70 's gem were stunningly gross",
#   'direction is completely uninspired . not recommended'],
#  ['and gives a refreshing view of cop',
#   'give this one 9/10 simply because it'],
#  ['tedious and redundant mess with mediocre slashing'],
#  ['\x96 a large junk dealerhip market and',
#   'call them `` outer space action figure',
#   'but generally , endless patter is not'],
#  ['that martha is badly underdeveloped and does'],
#  ['first reason : boring . barely anything',
#   'dead body . boring ! ! !',
#   ', the story uninteresting , the duologue',
#   'so as to avoid renting another movie'],
#  ['mysterious signal from outer space . they',
#   "'' is remarkably dull . *** end"],
#  [''],
#  ['5 of the worst movie i have',
#   '1 . ) incoherent and totally non-sensical',
#   'the need to insult every chance i'],
#  [', best to avoid at all cost'],
#  ['some horror and awful colors.. dear friend..'],
#  ['was in film noir , a genre',
#   'and optimism . noir was neurotically charged',
#   'to destiny . noir is about regress',
#   'is fraught with noir anxiety . noir',
#   'noir anxiety . noir is often considered',
#   'to witness.as in noir , his anxiety',
#   'masculinity , revealing pointless elaborate ritual at'],
#  ['the film seems pointless and the advert'],
#  ['one of the funniest and most entertaining'],
#  ['film . an incoherent storyline does not',
#   'is a jumbled mess that i am',
#   'most are particularly wooden . some though'],
#  ['mall in the dull finale.a fictional town',
#   'weezil.this is just junk , and proof'],
#  ['is down right awful . and btw'],
#  ['hollywood crap , uninteresting , childish ,',
#   ', childish , poorly conceived and in',
#   ', flat out laughable . much like'],
#  ['movie is still excellent . it had'],
#  ['town , he steals the identity of',
#   'ustinov manage to avoid prosecution and lives'],
#  ['is still pretty awful repugnant stuff .',
#   'turd as a mst3k style making fun'],
#  [', slow , boring , is the',
#   ', is the worst example of the',
#   'the kind of pretentious heavy handed art',
#   'train wreck of endless slow motion zoom',
#   'snapshot of the worst ( or best',
#   'overacting or the incredible awfulness of his'],
#  ['a cheap , boring and unoriginal show',
#   'responsible for the worst australian film in',
#   '- not even mildly amusing . it',
#   'bad and , worst of all ,',
#   'show being given 10/10 on imdb .',
#   'this show . avoid the show at'],
#  [', frank still steals the acting dishonours'],
#  ['was it is rare for a film'],
#  ['on a very rare occasion does an',
#   'is just totally boring to watch.a detective',
#   'one of the worst in x-file history'],
#  ['side , quite boring ; to my'],
#  ['with a decent balance of laugh ,',
#   ', such as obnoxious sportcaster ranch wilder'],
#  ['to see some badly made film but'],
#  ['out , greatly appreciated . and it'],
#  ['kind of rendered laughable , especially when'],
#  ['it is patently awful ! ! nothing',
#   'mean and only teach yoga to hot',
#   'that is how forgettable this is )',
#   'is the most unconvincing record exec ever'],
#  ['a movie this awful in a long',
#   'is that astoundingly awful . mira sorvino',
#   "'s blank and wooden acting surely must",
#   'her accent was awful and her sex'],
#  ['producer of this stinker turn this into',
#   'into such a dull story ? glenn',
#   ', is given awful writing material to'],
#  ['ribbing from the mst3k crew for his',
#   'phone calls or unconvincing special effect with'],
#  ['roy is and underrated epic of passion'],
#  ['was not exactly appreciated . fan of',
#   'a chance . furthermore , this version'],
#  ['it was so poorly done . i', 'truly be the worst movie ever made'],
#  ['hilliard was rather miscast in this as',
#   'moving and perfectly executed and i often',
#   "'s talent were endless ! overall ,"],
#  ['the world for wasting the film this'],
#  ['stalk somebody as dull as donna.-high school',
#   'is my utter boredom with everything .',
#   'wipes up his mess between scene .',
#   "brittany snow 's unconvincing performance ? i"],
#  ['what seemed rather boring suddenly turns very'],
#  ['acting was the worst , the effect',
#   'guy was the worst actor ever ...',
#   'one is the worst i have seen..and'],
#  ['stuck in the stupidity of her cruel'],
#  ['of such an awful film ? i', 'being in an awful movie such as'],
#  ["same is an insult to everyone 's"],
#  ["is so very rare for a 'guy"],
#  ['fan who like poorly scripted , poorly',
#   'poorly scripted , poorly shot indy film'],
#  ['film is an awful , ignoble american', '. but not surprisingly ... why was'],
#  ['ready . so trite , so standard',
#   'there are some mildly entertaining special effect'],
#  ['enough , the worst edit in memory',
#   'it commits the worst sin of all',
#   '. what a waste of effort .'],
#  ['is definitely better appreciated that way .'],
#  ['of cult cinema and/or bad movie-making ,',
#   'the most notoriously awful cult movie ever',
#   "'' is deliberately awful . right from",
#   'and insufferably amateurish mess . the quality'],
#  ['a bunch of superb actor we have'],
#  ['weak . the worst part is when', ', who are incredible coward ; especially'],
#  ['the brasília film fest in november 2001.'],
#  ['and not , surprisingly for the reason',
#   'movie `` definitely lacks good-looking female .'],
#  ['movie with special affect and mountain of',
#   "'' ( another excellent john water film"],
#  ['to be like batman . the fact'],
#  ['the character are forgettable , the writing'],
#  ['to show how pathetic a life rosetta',
#   'over-hyped film of boredom . it was'],
#  ['nose after her insult maggie by thinking'],
#  ['scheme.3 . a surprisingly good cast.4 .',
#   'expecting to be appreciated by its effort',
#   'tradition in this awful matter at the',
#   'the scene that steals the movie with'],
#  ["it was `` boring '' after you"],
#  ['three go through disappointment by being unprepared',
#   'kristin ) are disappointing . they do',
#   'fishburne was woefully miscast here as the',
#   'did so quite badly . it was'],
#  ["it was the excellent 'gremlin'.then came the",
#   "not forget the lousy 'ghouly'.but the complete",
#   'rather bland and poorly detailed , as'],
#  ['role . i appreciated his energy and'],
#  ['referred to are poorly done and a',
#   'movie are generally poorly written and lack'],
#  ['. easily the worst automotive movie or'],
#  ['to life the excellent acting of robert'],
#  ['venture off his ideal way of life', 'tv since the teach did not give'],
#  ['mind as the worst movie ever made', 'it is the worst movie i have'],
#  ['the story is excellent and the original',
#   'and is really refreshing if you have',
#   'this is a pathetic copy . no'],
#  ['the stereotype but fails with horrendous acting'],
#  ['. it was dull and boring.with some'],
#  ['steve touissant ) steals it and plots',
#   'fighter jet , awful camera work ,',
#   ', risible , unconvincing fight scene that',
#   'trademark and a boring , sleep inducing',
#   'more of these awful european lensed action',
#   'his next film prince of pistol might',
#   'a flight that fails to even take'],
#  ['rated this film 7/10 which is an',
#   'an average of 8/10 for screenplay ,',
#   'was calculated at 4/10 for all the',
#   'richman who was excellent at 8/10.also i',
#   "`` suevia film noir cine negro ''"],
#  ['! thomas was executed in 2000 !'],
#  ['dragon and iron monkey . well worth'],
#  ['the monologue were dull but delivered with'],
#  ['to watch-the most incredible bit is when'],
#  ['a decent primary and/or secondary school education'],
#  ['that it would affect him , and',
#   "think the play lacks ? '' ``",
#   'it starts to affect those around her',
#   "'will she be alright ? ' perhaps",
#   ', blur together wonderfully . opening night'],
#  ["'wisdom ' is laughable . `` move", 'is a hard-to-find gem . i will'],
#  ['though . really boring and poorly written',
#   'really boring and poorly written . it'],
#  ['to vomit ... 1/10 ( 1 point'],
#  ['this was an excellent idea and the'],
#  ['for his patients.this delightful semi-original and entertaining',
#   'are only sporadic uninteresting moment , and',
#   'have added more credibility to the flick.\x91the',
#   'find this a refreshing change , as',
#   '. a seldom dull and generally well'],
#  ['boss , who surprisingly was not given',
#   'point of being pointless in the film',
#   'among the most poorly executed in the',
#   'the most poorly executed in the bunch',
#   ', pays a wonderfully well-executed tribute to',
#   ', but it fails most apparently in'],
#  ['amazing animation and superb action , but'],
#  ['order . the worst thing was the', 'happened . the worst example of this'],
#  ['sister ) are excellent choice to begin'],
#  ['me enormously . avoid this film at'],
#  ['character is very poorly written . william',
#   'story . ustinov steals the show ,',
#   'of his many pointless cameos ( his'],
#  ['one of the worst movie ever .',
#   'character whatsoever . endless time without dialog'],
#  ['just did an awful job in this',
#   'was not completely awful , but it',
#   'ending was especially disappointing . as in',
#   'over in an endless loop ? it',
#   'was an extremely disappointing end and did'],
#  ['familiar from brit dramas and comedy ,'],
#  ['accounted for their excellent chemistry together on',
#   'are filled with excellent music , and',
#   'pudgy boy who steals glance at orked.and',
#   ', and a rare one that i'],
#  ['this match was boring and it has'],
#  ["'' is genuinely haunting . this dimension"],
#  ['one of the worst movie of all'],
#  ['was there . poorly written and directed.my'],
#  ['scott does an incredible job as scrooge',
#   'entire cast is incredible . the tiny'],
#  ['being makes for dull story telling .'],
#  ['is almost totally devoid of the ``'],
#  ['think the biggest disappointment in this film'],
#  ['that is so trite and predictable ('],
#  ['the character are wonderfully developed . the'],
#  ['surfer could become boring . although the'],
#  ['truly , truly dire canadian-german co-production ,',
#   ', though the incoherent script , useless',
#   'useless direction and appalling music ( check',
#   ', but she fails on both count'],
#  ['earth is in dire strait . something',
#   '? ) his laughable attempt to use',
#   'and are the worst scene in the',
#   'only are they boring , but they',
#   'the utmost of stupidity , particularly in',
#   'spaceship is the worst effect to come',
#   'just get so lousy that your jaw'],
#  ['cgi is done poorly , the acting'],
#  ['cast filled with excellent supporting actor and'],
#  ['it an easy 8/10 just for being'],
#  ['call it the worst movie ever made', 'movie before they waste a dime on'],
#  ['', 'half but is superb in emotional scene'],
#  ["rose 's illiantly haunting and poetic paperhouse"],
#  ['not just a superb film but is', 'study and is flawless in the way'],
#  ['b picture , noir type stuff with', 'duryea who almost steals the film .'],
#  ['this was an excellent film ! i',
#   'this film was superb from start to',
#   'laurence fishburne was superb as tanny brown',
#   'was the real gem in the film',
#   'scene , just superb ! ! !',
#   'to start . excellent cast in this'],
#  ["just the umpteenth pointless post- '' scream",
#   'with absolutely no redeeming value whatsoever .',
#   'is just plain boring ! as you',
#   'steal idea from junk like `` ikwydls',
#   'girl in this junk are , apart',
#   'realize that the delightful spirit of the'],
#  ['intruder contains a haunting guitar soundtrack by',
#   '- `` your worst enemy are hiding'],
#  ['serve as an excellent way to present'],
#  ['complicated and needless pointless plan ala scooby-doo',
#   'god what a waste of time .'],
#  ['urbibe presents a tight and controlled film'],
#  ['this is an excellent series , though'],
#  ['has not been appreciated for its comic'],
#  ['plan 9 from outer space is fun'],
#  ['were a bit dull , but when'],
#  ['one of the worst movie i have',
#   'it is extremely boring with lot of',
#   'with lot of boring dialog and has',
#   'character and a laughable looking creature .',
#   'and was quite laughable plus his character',
#   'richard . overall avoid this piece of'],
#  ['particular was absolutely dreadful , especially in'],
#  ['still just a waste of time .'],
#  ['so why the 3/10 rating ? because',
#   ', do not waste your money on',
#   'did not get ripped off , but'],
#  ['this is an awful movie , for'],
#  ['mats.abandoned on a junk planet , he',
#   'space hippie that teach him about gardening'],
#  [', would become boring and depressing even.my'],
#  ['bat - on balance , not a',
#   'them.prank is a badly made slasher movie',
#   'dvd even more pointless because , let',
#   'violence is a waste of time .'],
#  ['the acting is superb . all three', 'garber ) are excellent in their role'],
#  ['the dandys are alright ) . everything'],
#  ['script had such excellent dialogue.i hope rachel'],
#  ['implemented in the worst possible way .',
#   'find a cohesive balance so the line'],
#  ['bad therefore it fails in it is'],
#  ['acting is uniformly dull , the script',
#   ', the script uninspired . the film'],
#  ['it was a waste not to watch', 'he has less redeeming quality than the'],
#  ['the drama is surprisingly addictive and if',
#   'other female cast dramas such as sex'],
#  ['what a major disappointment ! 1 )', '. do not waste your time on'],
#  ['makes good medical dramas tick - dramatic'],
#  ['this was so surprisingly well focused that',
#   'that were not excellent , but nothing'],
#  ['is still really dreadful . i gave',
#   'it and felt generous . whatever ,',
#   'squishes the whole mess into about an',
#   'hour of truly awful amateur video.you would'],
#  ['perennial ) is wonderfully hateful as the'],
#  ['a 10 ( excellent ) was clearly'],
#  ['suffer from the worst affliction a horror',
#   'the audience ? boredom . unless of',
#   "'' was a disappointment . everything was"],
#  ['performance is so excellent that you will'],
#  ['of it looked remotely real , or', '. do not waste your time.my grade'],
#  ['first half is driven by the excellent',
#   'driven by the excellent performance of dutton',
#   'forgotten in a dull , incoherent ,',
#   'a dull , incoherent , and downright',
#   ', and downright awful 2nd half .',
#   '. rating : 4/10 . not rated'],
#  ['is a complete waste . okay ,', 'to stop the hype . but watch'],
#  ['are not the worst movie ever made'],
#  ['it was really refreshing to see a', 'movie deserved an 8/10 i wish more'],
#  ['one of the funniest movie , i´ve'],
#  ['with this b noir starring ella raine',
#   "of her `` noir '' counterparts.siodmak 's"],
#  ["movie was rather awful vipul shah 's"],
#  ['they would be superb , as the', 'hang in the balance . unlike many'],
#  ['one of the funniest movie that i'],
#  ['is not the worst film in the',
#   'after being force-fed junk for several year'],
#  ['path or , worst , that are', 'in search of prince charming and a'],
#  ['one of the funniest movie i have', 'most of the funniest line . the'],
#  ['', 'to fix this mess . problem is'],
#  ['kind of crap fest . i was',
#   'farting and a pathetic lead character who',
#   'a smart , surprisingly original movie about'],
#  ["each other 's flawless physique in their",
#   'zee bargain basement noir , yet looks'],
#  ['really hate a dull bad horror movie'],
#  ['thing around and excellent cinematography . in'],
#  ['lahem is an awful movie.this is only',
#   'scene are very rare in arab cinema',
#   'film as an awful one are not'],
#  ['jealous hugo matuschek driven to nervous eakdown',
#   'but loyal pirovitch wonderfully ( a lubitsch'],
#  ['the acting was superb but only a', 'lost in this mess . i found'],
#  ['no way to avoid the overtly religious'],
#  ['saw was a boring tale about a',
#   'to put it mildly ) pretty poor',
#   'a slow moving dull story which bored',
#   'long ago . dull and slow .'],
#  ['actually becomes very boring after 45 minute'],
#  ['one of the worst movie i have'],
#  ["not forget the awful movie from '66"],
#  ['really appreciate the excellent makeup and gore',
#   ', and the excellent transfer adds to',
#   'kind.there is some excellent set piece and',
#   'exotic locale , excellent set design ,',
#   'great cinematography , wonderfully cheesy acting ,',
#   'kick butt , excellent music , and'],
#  ['most unfitting , pretentious score ever written',
#   'acting and the laughable screenplay.in the end'],
#  ['fez was thoroughly uninteresting and the character',
#   'had do really awful joke , usually'],
#  ['school just to teach them a lesson'],
#  [''],
# ...
#   'a bit more wooden than where the'],
#  ['terrible , terrible batman : dead end', 'makes up for batman : dead end'],
#  ['? a simply awful movie is what.as',
#   'for those read dull and contrived ,',
#   'and contrived , dull and contrived and',
#   'and contrived and dull and overly contrived.i',
#   'seen the completed mess realised that they'],
#  [", trying to balance their daughter '",
#   'many more contribute wonderfully to the film'],
#  ['a theme and ideal central to the',
#   "gretchen mol 's excellent performance of bettie"],
#  ['in for a disappointment , the other'],
#  ['the italian is incredible and really places'],
#  ['title for the worst show i have',
#   "laughlin '' was ripped off from something"],
#  ['one of the funniest comedy series the',
#   'funny man ripthis underrated show has sadly'],
#  [', boasts an awful accent and is',
#   'is a really awful villain.i honestly tried'],
#  ['that is used poorly in this umpteen',
#   'horrible , effect laughable , and the',
#   'earth as the worst i have witnessed',
#   'hot ! and surprisingly , he is',
#   'some of the worst i have ever'],
#  ["'what is the worst movie ever made",
#   'just how utterly devoid of intellect and'],
#  ['been tied for worst movie ever for'],
#  ['give this film 10/10 as my uncle'],
#  ['constant is the generous helping of sociological',
#   '. acting is uninspired and perfunctory .'],
#  ['actually found it mildly entertaining ( emphasis'],
#  ['or the other cardboard gangster that inhabited'],
#  ['one is the worst one of them'],
#  ['. an utter waste of time and'],
#  ['. brosnan is wonderfully crass and crude',
#   'anti-hero and kinnear delightful as his counterpart',
#   'the ending is delightful and with some'],
#  ['one of the funniest movie i have',
#   'hilarious but the funniest part of the'],
#  ['this movie was awful . the ending',
#   'their performance were excellent ! the only',
#   'on a god awful storyline ... or',
#   'entire cast were excellent , but they',
#   'on such a disappointment of a movie'],
#  ['is a very rare horror/chiller from 1990'],
#  ['long pause and tight camera shot equaled',
#   'like amber benson waste time trying to'],
#  ['this is a superb movie , suitable'],
#  ['that despite the rare bad story line'],
#  ['those story so awful it fascinates.zoe mclellan'],
#  ['very best bbc dramas . and the', 'they move like wooden soldier and speak'],
#  ['great actor in excellent film , even', 'truly a big waste of time .'],
#  [') is incredibly obnoxious . also roddy',
#   'song ( while forgettable ) are pleasant'],
#  ['of the most underrated film of the',
#   '*grits teeth* ) superb as the tortured',
#   '. law is surprisingly menacing as the'],
#  ['at a film fest in ca .', 'film is god awful . it is'],
#  ['really silly and trite line . something'],
#  ['bloody teenkill , laughable plotting and an',
#   'up dead or behave strangely . this'],
#  ['he gave an excellent performance , but',
#   'the result is pathetic , just like'],
#  ['one of the worst 5 movie i', ', which is poorly written , slow'],
#  ['not glamorize , hype , or sentimentalize'],
#  ['it was incredibly dull and boring .', 'incredibly dull and boring . a few'],
#  ['promised ... blue monkey ... has nothing',
#   "mood for more monkey hijack 80 's"],
#  ['banal , often pointless story . anyone',
#   'amateur so utterly awful in his movie',
#   'is once again appalling sloppiness . pasolini',
#   'even notice the awful acting ? )',
#   'for hypocrisy and stupidity ? where does'],
#  ['to be . worst of all ,',
#   'may inhibit better dramas from being distributed'],
#  ['to be completely pointless . there is'],
#  ['this was extremely poorly made . it', '. even the worst movie have at'],
#  ['terrifying.spoiler section the stupidity of the hero',
#   'hero is near incredible . he is'],
#  ['get their heart ripped out is amusing',
#   'does have one redeeming factor ... oh'],
#  ['one of the worst movie i have',
#   'is a massive disappointment - along the',
#   "'' do not waste your time or"],
#  ['rather lame and uninspired . this is'],
#  ['by far the worst film at the', 'not find a redeeming feature of this'],
#  ['adaptation is handled poorly , painful ,'],
#  ['end it became trite . although turturro'],
#  ['i rate this 8/10 . rated r'],
#  ['special effect are incredible for the era'],
#  ['unbelievable , and incoherent spanish production about'],
#  ['meant to be incredible , but i'],
#  [', a hugely disappointing sequel to the', 'give this a 3/10 , it just'],
#  ['gave it a 8/10 . that is'],
#  ['supporting cast was superb . the strange'],
#  [', the most disappointing tr game yet', 'game so why mess with it .'],
#  ['with bogie clearly miscast also , it'],
#  ['is absolutely the worst movie i have'],
#  ['it is a superbly enjoyable movie with',
#   '. plenty of superb action and sly'],
#  ['the movie is mildly entertaining in its'],
#  ['quite possibly the worst movie i have',
#   "movie 's only redeeming factor is that"],
#  ['which is already uninteresting and badly told',
#   'already uninteresting and badly told into something'],
#  ['across this bizarre gem of a film.this'],
#  ['has done an incredible job with hammond'],
#  ['is a totally delightful and unexpected film',
#   'there are some excellent set piece ,'],
#  ['the famous short batman dead end ,',
#   'before the official batman 5 film. --'],
#  ['but besides the incredible performance , another',
#   'film is the incredible music . this'],
#  ['destination in jeep driven at 3 mph', 'is the only redeeming feature . as'],
#  ['has made some excellent film . i',
#   'van sant are incredible visionary and tower',
#   'sometimes think the worst and/or the best',
#   'think the worst and/or the best and'],
#  ['it was so lousy that i shut', 'to be so boring in this film'],
#  ['blockheads.the story also fails to ing closure',
#   'the ending was excellent and the result',
#   'circumstance became more dire . beckinsale ,',
#   'film.bill pullman was miscast as the lawyer'],
#  ['features the always delightful tierney . she'],
#  ['was truly a gem of a movie.and'],
#  ['to express how dull , depressing and'],
#  ['it is a 10/10 are lying because',
#   'it an absolute mess . i had',
#   'the actor did alright . george clooney'],
#  ['hour but completely lacks the action ,', '. he is awful when he tries'],
#  ['talent of a superb cast , and',
#   ', the movie fails dismally on the',
#   'dismally on the credibility score . perhaps'],
#  ['this is his ideal , in the', 'cowboy is an excellent film portraying the'],
#  ['would be a waste of time .',
#   'piper perabo completely fails in convincing one'],
#  ["1922'one thing more disappointing than the photography",
#   'mostly flat and wooden . when it',
#   'some of the worst silent film ,',
#   'is here merely dull to watch .',
#   'attained true stardom.the worst and most amusing',
#   'moral structure , wooden acting and bad',
#   'it seriously . boring , slow and'],
#  ['other than the laughable screenplay , it'],
#  ['brook , was excellent . the cast', 'up to the funniest standard also .'],
#  ['character , the excellent performance of the'],
#  ['give it an 8/10 . go see'],
#  ['the 1949 film noir , `` criss',
#   'latter to be disappointing but it was',
#   'disqualified for film noir status . the'],
#  ['of the most awful , amateurish film',
#   'it dies from boredom . every character',
#   'moron . one pointless subplot shows a'],
#  ['character was the worst drawn . it',
#   'used but not appreciated , and finally'],
#  ['the category of worst movie that i'],
#  ["'s most recent stinker , the girlfriend",
#   "soderbergh 's repetitious waste of ( hd",
#   'if not deliberately insult , his audience',
#   '2008 ) gleefully fails to deliver .'],
#  ['girl is the worst actress i ever',
#   'appreciate your time avoid this movie ,'],
#  ['jennifer ( a superbly moving performance by',
#   'exceptional , with excellent support from edward'],
#  ['one of the worst film ever made'],
#  ['is just plain pathetic . the little'],
#  ['not-so-mysterious , but surprisingly narrow-minded cult of'],
#  ['boyer are a superb screen couple .',
#   'supporting cast is excellent : basil rathbone',
#   "'s are both rare and lovely to"],
#  ['is a terrible waste of time and'],
#  ['hyena . the worst digger in the', 'figure . they teach him the art'],
#  ['phillip makes an excellent alicia and erika'],
#  ['. because the pathetic comedy will make'],
#  ["' is a superb film . a",
#   'jeff bridge is excellent as the boss',
#   '! anderson is delightful . she does',
#   "' is a excellent entertainer . do"],
#  ['we make bloody awful movie ! this',
#   '. we produce pretentious second rate piffle'],
#  ['at some grease monkey , but that'],
#  ['film i was mildly impressed . but',
#   'with a pet monkey ! the list',
#   'a very harsh 1/10 , the film'],
#  ['basic premise is alright actually , it',
#   'survive and the excellent gory killer bigfoot',
#   'the start look awful and the yeti',
#   'scene including a ripped off arm ,',
#   'head , a ripped out heart ,'],
#  ['you not to waste your time on'],
#  ['moment that ever existed and will exist'],
#  ['i found it unfunny and crude for', 'few homosexual ( unfunny ) joke .'],
#  ['for ? an excellent movie for pre-pubescent',
#   'obviously the most haunting image from the'],
#  ['usually a very boring movie that preaches'],
#  ["'s mom is laughable - i am"],
#  [''],
#  ['these underdog doing badly as the good',
#   'and leaves a dull pain in your',
#   '. plain . boring . something you',
#   'nap . as dull as the day'],
#  ['as a truly troubled character . he',
#   'as a ridiculously pathetic character , but'],
#  ['effect ? absolutely awful in my opinion',
#   'poor dialogue , awful acting , what',
#   'this was simply awful . i hope',
#   'unrealism and truly awful acting makes for',
#   'makes for an awful experience . save'],
#  [', entwined with superb animation and the',
#   'animation and the excellent voice talent of',
#   'also presented in superb cinemascope format ,',
#   'end are the funniest part of the'],
#  ['what an incomprehensible mess of a movie'],
#  ['such a ridiculous waste of money .'],
#  ['dozen or so worst movie ever released',
#   'jellybean plus inconceivably awful voiceover narration by'],
#  ['one of those awful relentless flat-out ham-it-up'],
#  ['navy , is troubled . he is'],
#  ['than with this pretentious crap ... must'],
#  ['story of the worst kind of depravity',
#   'was about the worst episode , closely',
#   "it through . 1/10 for 'fun '",
#   "for 'fun ' 8/10 for displaying 'man"],
#  ['just a hollywood cardboard piece of propaganda'],
#  ['for his lost ideal , kobayashi (',
#   'when his client fails him and his',
#   'kobayashi¡¦s effort finally fails , and he',
#   'enlightens us and teach us something .'],
#  ['was kind of boring at first but', 'going it really hooked me . i'],
#  ['will find her prince . the chance', 'comes when the prince of the kingdom'],
#  ['. the only redeeming characteristic i find'],
#  ['it will have redeeming amusement value .', 'and just plain dull as a film'],
#  ['firing a muzzle-loader badly . was this',
#   'spoof . the worst was when diamond',
#   'out of this dire situation ? stay',
#   'interesting and utterly boring . european conquered',
#   'against stone and wooden weapon . do'],
#  ['say for this dull witted local ``'],
#  ['thought taylor was underrated as an actor',
#   'solid , almost dull leading man type'],
#  ['weariness at the disappointing behavior of his'],
#  ['film was simply awful - i say',
#   '- it was awful . matthew modine',
#   'contender for the worst movie i have'],
#  ['out to be pointless , both from'],
#  ['( who looks surprisingly like willie nelson'],
#  ['had a nail driven into my pee'],
#  ['enjoyed this nor appreciated the unusual approach'],
#  ['her girlfriend-in-cahoots is dull , and sadly',
#   'and when it fails , like in'],
#  [') been the worst . if i'],
#  ['it was very disappointing . my whole',
#   "'s girlfriend , appalling , and honestly"],
#  ['some of the worst actor i´ve seen'],
#  ['actually not the worst i have seen',
#   'is not the worst i have seen',
#   'it was the worst i had ever',
#   'were not too poorly done , but'],
#  ["of coleridge 's haunting poem . the",
#   "michael redgrave 's superb narration , are",
#   'to view this excellent visual work.in the',
#   'work is indeed rare ; that is'],
#  ['acting is almost awful except for the'],
#  ['but it is obnoxious . by the',
#   'the list of worst film of 2008',
#   'the time for dull acting , cheap'],
#  ['sound are rather pathetic , and it'],
#  ['even at his worst , kurosawa is'],
#  ["and ted 's excellent adventure ' ,",
#   "terry gilliam 's excellent film , '12",
#   "film , '12 monkey ' , it",
#   "story , '12 monkey ' is unclear",
#   "of both '12 monkey ' and the",
#   "jone . '12 monkey ' is a"],
#  ['looks . it fails . what also', '. what also fails is an attempt'],
#  ['character being one dimensional and you could',
#   '`` part.overall a pointless watch . it'],
#  ['generic soundtrack is laughable , the direction'],
#  ['the actor were incredible , the story'],
#  ['of the most awful history movie in'],
#  ["is definitely the worst movie adam 's", '. do not waste your time .'],
#  ['seen such a boring movie in my'],
#  ['film is pretty awful , the only',
#   "it that `` awful '' look ,",
#   'the script is dire ... ..this film'],
#  ['credible and fairly boring story about a'],
#  ['risk of sounding trite , `` they',
#   'great storyline , incredible cast of character',
#   'soundtrack has a haunting quality to it'],
#  ['one of the worst film i have', 'it was pretty boring and disturbing ('],
#  ['was not the worst movie i have'],
#  ['age to have appreciated a movie about'],
#  ['getting them . badly acted , poorly',
#   'badly acted , poorly filmed , unbelievable',
#   'real thing . avoid this bilgewater .'],
#  ['bad scripting and laughable moment . one'],
#  ['muni do an excellent job acting but'],
#  ['. the only redeeming aspect to this'],
#  ['the acting is awful ( 9 )'],
#  ['up with the awful hair cut ,', 'make money to teach kid how to'],
#  ['', 'reid gives an excellent performance in spite'],
#  ['by it is worst moment . there',
#   'is performing some wonderfully subtle comedy in'],
#  ['pole of the noir universe ) .',
#   ', and dyed-in-the-wool noir ( laura ,',
#   "first dubbed ` noir , ' was",
#   'big apple - noir , like several'],
#  ['this would be awful , but the',
#   'that is also pointless . on the',
#   "b 's amazingly awful book , killing"],
#  ['it does not teach anything . it'],
#  ['one that ends badly and the final'],
#  ['. in a rare feature of early',
#   'movie are virtually flawless , from the',
#   'way to the superb direction and story',
#   'is still a delightful entry into the',
#   'accompanied by a wonderfully arranged soundtrack ,',
#   'an entertaining and haunting feature length movie',
#   'this segment a rare 10/10.the film is',
#   'to fear the worst . this segment',
#   'could have been executed better but nonetheless',
#   'segment has its redeeming feature . horror',
#   'that feature an incredible cast , great'],
#  ['one of those rare film that keeps'],
#  [''],
#  ['that world.beautiful and haunting film . i'],
#  ['mediocre is the excellent ossie davis .', 'it is so poorly done in every'],
#  ['. do not waste your money or'],
#  ['did his usual uninteresting , cardboard character',
#   'usual uninteresting , cardboard character , punctuated',
#   'money in the cardboard acting style .'],
#  ['have always had incredible ambition in their',
#   'monster coming from outer space and elsewhere',
#   'extremely awkward and laughable , but well'],
#  ['fragrant , and surprisingly fresh , the'],
#  ['there being any redeeming quality to this'],
#  ['stupid enough to waste $ 8 on'],
#  ['alone has to teach them the skill',
#   'they do not teach about why animal',
#   'and try to teach the important lesson'],
#  ['away the special affect , were as'],
#  ['has a similar affect on the young'],
#  ['boy was i hooked ! ! i', 'i find it mildly torturous and cruel'],
#  ['what an unfortunate mess is `` shiner',
#   'the two most poorly written character offering',
#   'line with an appalling lack of skill',
#   'dropped in to avoid the film being'],
#  ['unless you have incredible wilpower . before'],
#  ['a bit old fashioned and contrived .', 'farrell is an awful person . she'],
#  ['round in the worst clothing i have'],
#  ['davis jr. and jackie onasis called ``'],
#  ...]
